# %%
# !unzip /content/drive/MyDrive/Trainning_Flame/FLAME.v1i.yolov11.zip -d /content/

# %%
pip install ultralytics

# %%
# !rm -rf /content/runs

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model with GPU
results = model.train(data="/content/data.yaml", epochs=100, imgsz=960, batch=16, device=0)
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

def evaluate_model():
    model = YOLO("/content/runs/detect/train/weights/best.pt")

    # Thực hiện đánh giá trên tập test
    metrics = model.val(
        data="data.yaml",
        split="test",  # dùng tập test
        imgsz=960,
        batch=16,
        plots=True     # xuất biểu đồ: confusion matrix, PR curve...
    )

if __name__ == "__main__":
    evaluate_model()
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2872.5±627.5 MB/s, size: 188.2 KB)
# val: Scanning /content/test/labels.cache... 207 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 207/207 307.2Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.1it/s 6.1s
#                    all        207       1088      0.909      0.858      0.934      0.661
# Speed: 7.0ms preprocess, 9.2ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /content/runs/detect/val

# %%
# !zip -r runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/val_batch2_labels.jpg (deflated 4%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 4%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 2%)
#   adding: content/runs/detect/train/results.png (deflated 8%)
#   adding: content/runs/detect/train/train_batch9271.jpg (deflated 6%)
#   adding: content/runs/detect/train/train_batch9270.jpg (deflated 4%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 4%)
#   adding: content/runs/detect/train/train_batch9272.jpg (deflated 3%)
#   adding: content/runs/detect/train/BoxF1_curve.png (deflated 16%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 11%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 11%)
# ...
